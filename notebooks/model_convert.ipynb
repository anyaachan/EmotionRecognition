# %%
# Standard Libraries
import logging
import re
import string
import random
import json

# Data Manipulation and Analysis
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# Machine Learning Models
from sklearn.ensemble import RandomForestClassifier

# Deep Learning Libraries
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loaded_model = tf.keras.models.load_model("/Users/anna-alexandradanchenko/local/EmotionRecognition/model/model.keras")
prediction = loaded_model.predict([[2, 3, 4, 5, 6]])
prediction
# Out:
# 1/1 [==============================] - 2s 2s/step
# array([[0.04974138, 0.01950196, 0.12146705, 0.04847442, 0.6660178 ,
#         0.07430879, 0.02048855]], dtype=float32)

# %%
with open('/Users/anna-alexandradanchenko/local/EmotionRecognition/model/tokenizer_dictionary.json') as tokenizer_dict:
    data = json.load(tokenizer_dict)

    inverted_dict = dict((v,k) for k,v in data.items())
    print(inverted_dict)
# Out:
# {'i': '1', 'feel': '2', 'and': '3', 'the': '4', 'to': '5', 'a': '6', 'that': '7', 'of': '8', 'feeling': '9', 'am': '10', 'my': '11', 'it': '12', 'not': '13', 'in': '14', 'is': '15', 'have': '16', 'like': '17', 'was': '18', 'for': '19', 'so': '20', 'this': '21', 'you': '22', 'but': '23', 'me': '24', 'with': '25', 'be': '26', 'about': '27', 'do': '28', 'on': '29', 'as': '30', 'just': '31', 'at': '32', 'when': '33', 'are': '34', 'or': '35', 'all': '36', 'because': '37', 'more': '38', 'what': '39', 'they': '40', 'can': '41', 'by': '42', 'really': '43', 'up': '44', 'know': '45', 'if': '46', 'would': '47', 'he': '48', 'how': '49', 'out': '50', 'will': '51', 'name': '52', 't': '53', 'been': '54', 'get': '55', 'very': '56', 'time': '57', 'people': '58', 'little': '59', 'from': '60', 'had': '61', 'myself': '62', 'her': '63', 'now': '64', 'one': '65', 'did': '66', 'love': '67', 'think': '68', 'being': '69', 'them': '70', 'there': '71', 'we': '72', 'still': '73', 'want': '74', 'him': '75', 'som
# ...

# %%
with open('/Users/anna-alexandradanchenko/local/EmotionRecognition/model/tokenizer_dictionary.json', 'w') as file:
    json.dump(inverted_dict, file)
