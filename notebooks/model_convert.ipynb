# %%
# Standard Libraries
import logging
import re
import string
import random
import json

# Data Manipulation and Analysis
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# Machine Learning Models
from sklearn.ensemble import RandomForestClassifier

# Deep Learning Libraries
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open('/Users/anna-alexandradanchenko/local/EmotionRecognition/model/tokenizer_dictionary.json') as tokenizer_dict:
    data = json.load(tokenizer_dict)

    inverted_dict = dict((v,k) for k,v in data.items())
    print(inverted_dict)
# Out:
# {'i': '1', 'feel': '2', 'and': '3', 'to': '4', 'the': '5', 'a': '6', 'that': '7', 'of': '8', 'feeling': '9', 'am': '10', 'my': '11', 'it': '12', 'not': '13', 'in': '14', 'is': '15', 'have': '16', 'like': '17', 'for': '18', 'so': '19', 'was': '20', 'me': '21', 'you': '22', 'this': '23', 'but': '24', 'with': '25', 'be': '26', 'about': '27', 'do': '28', 'on': '29', 'as': '30', 'just': '31', 'at': '32', 'when': '33', 'are': '34', 'or': '35', 'all': '36', 'because': '37', 'more': '38', 'can': '39', 'they': '40', 'really': '41', 'up': '42', 'what': '43', 'if': '44', 'know': '45', 'would': '46', 'he': '47', 'will': '48', 'by': '49', 'out': '50', 't': '51', 'been': '52', 'get': '53', 'very': '54', 'time': '55', 'how': '56', 'name': '57', 'people': '58', 'myself': '59', 'from': '60', 'now': '61', 'had': '62', 'her': '63', 'being': '64', 'little': '65', 'one': '66', 'love': '67', 'them': '68', 'want': '69', 'did': '70', 'we': '71', 'think': '72', 'there': '73', '!': '74', 'who': '75', 'him': '76', 'still': '77', 'some': '78', 'she': '79', 'an': '80', 'even': '81', 'no': '82', 'much': '83', 'could': '84', 'going': '85', 'your': '86', 'way': '87', 'too': '88', 'something': '89', 'its': '90', 'life': '91', 'make': '92', 'things': '93', 'his': '94', 'bit': '95', 's': '96', 'has': '97', 'than': '98', 'go': '99', 'm': '100', 'cannot': '101', 'day': '102', 'back': '103', 'their': '104', '?': '105', 'see': '106', 'need': '107', 'only': '108', 'right': '109', 'should': '110', 'into': '111', 'good': '112', 'always': '113', 'other': '114', 'over': '115', 'then': '116', 'don': '117', 'also': '118', 'which': '119', 'say': '120', 'never': '121', 'were': '122', 'these': '123', 'got': '124', 'here': '125', 'work': '126', 'pretty': '127', 'after': '128', 'feelings': '129', 'our': '130', 'those': '131', 'someone': '132', 'most': '133', 'any': '134', 'though': '135', 'feels': '136', 'why': '137', 'again': '138', 'well': '139', 'around': '140', 'help': '141', 'today': '142', 'kind': '143', 'off': '144', 'down': '145', 'where': '146', 'made': '147', 'doing': '148', 'every': '149', 'having': '150', 'makes': '151', 'does': '152', 'look': '153', 'through': '154', 'anything': '155', 'take': '156', 'before': '157', 'person': '158', 'lot': '159', 'sure': '160', 'many': '161', 'getting': '162', 'less': '163', 'find': '164', 'actually': '165', 'last': '166', 'us': '167', 'happy': '168', 'thing': '169', 'home': '170', 'felt': '171', 'quite': '172', 'friends': '173', 'ever': '174', 'thought': '175', 'new': '176', 'said': '177', 'without': '178', 'enough': '179', 'better': '180', 'left': '181', 'first': '182', 'days': '183', 'such': '184', 'while': '185', 'away': '186', 'own': '187', 'sometimes': '188', 'bad': '189', 'come': '190', 'everything': '191', 'year': '192', 'long': '193', 'let': '194', 'world': '195', 'few': '196', 'same': '197', 'started': '198', 'trying': '199', 'remember': '200', 'http': '201', 'try': '202', 'years': '203', 'might': '204', 'rather': '205', 'since': '206', 'hate': '207', 'start': '208', 'tell': '209', 'family': '210', 'keep': '211', 'give': '212', 'times': '213', 'loved': '214', 'able': '215', 'angry': '216', 'sweet': '217', 'end': '218', 'already': '219', 'put': '220', 'everyone': '221', 'part': '222', 'may': '223', 'two': '224', 'making': '225', 'yet': '226', 'href': '227', 'week': '228', 'nothing': '229', 'another': '230', 'read': '231', 'night': '232', 'sad': '233', 'place': '234', 'maybe': '235', 'wanted': '236', 'post': '237', 'others': '238', 'heart': '239', 'god': '240', 'alone': '241', 'ill': '242', 'moment': '243', 'done': '244', 'hope': '245', 'hard': '246', 'old': '247', 'next': '248', 'stressed': '249', 'id': '250', 'agitated': '251', 'friend': '252', 'guess': '253', 'probably': '254', 'mean': '255', 'man': '256', 'point': '257', 'blessed': '258', 'accepted': '259', 'almost': '260', 'stop': '261', 'hurt': '262', 'school': '263', 'went': '264', 'thinking': '265', 'hot': '266', 'towards': '267', 'best': '268', 'hated': '269', 'w ...

# %%
with open('/Users/anna-alexandradanchenko/local/EmotionRecognition/model/tokenizer_dictionary.json', 'w') as file:
    json.dump(inverted_dict, file)
